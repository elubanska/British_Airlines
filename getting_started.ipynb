# %% [markdown]
# # Task 1
#
# ---
#
# ## Web scraping and analysis
#
# This Jupyter notebook includes some code to get you started with web scraping. We will use a package called `BeautifulSoup` to collect the data from the web. Once you've collected your data and saved it into a local `.csv` file you should start with your analysis.
#
# ### Scraping data from Skytrax
#
# If you visit [https://www.airlinequality.com] you can see that there is a lot of data there. For this task, we are only interested in reviews related to British Airways and the Airline itself.
#
# If you navigate to this link: [https://www.airlinequality.com/airline-reviews/british-airways] you will see this data. Now, we can use `Python` and `BeautifulSoup` to collect all the links to the reviews and then to collect the text data on each of the individual review links.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
base_url = "https://www.airlinequality.com/airline-reviews/british-airways"
pages = 3
page_size = 100

global rating, Aircraft, Class, Travel_type, Route, Date, comfort, staff, food, entertainment, wifi, ground_service, vfm, recommend

verified=[]
rating=[]
feedback=[]
Aircraft=[]
Class=[]
Travel_type=[]
Route=[]
Date=[]
comfort=[]
staff=[]
food=[]
entertainment=[]
wifi=[]
ground_service=[]
vfm=[]
recommend=[]

# for i in range(1, pages + 1):
for i in range(1, pages + 1):

    print(f"Scraping page {i}")

    # Create URL to collect links from paginated data
    url = f"{base_url}/page/{i}/?sortby=post_date%3ADesc&pagesize={page_size}"

    # Collect HTML data from this page
    response = requests.get(url)

    # Parse content
    content = response.content
    parsed_content = BeautifulSoup(content, 'html.parser')
    

    for row in parsed_content.find_all("div", {"class": "tc_mobile"}):
        my_data = {
            'Comment': parsed_content.find("div", {"class": "text_content"}).get_text()
        }
        #my_data2.append(['Comment', parsed_content.find("div", {"class": "text_content"}).get_text()])
        #print(my_data)
        #print(my_data2)
        my_data2=[]
        table = row.find_all('table')[0]
        my_data2.append(my_data)
        for tr in  table.select('table.review-ratings tr'):            
            header=tr.find('td',class_='review-rating-header').text
            if tr.find('td',class_='review-value') :
                value=tr.find('td',class_='review-value').text
            else :
                value=len(tr.find('td',class_='review-rating-stars').select('.star.fill'))
            my_data5 = {header:value}
            my_data2.append(my_data5)
            print(my_data5)
        
#        my_data = ({tr.td.text:len(tr.select('.star.fill')) for tr in table.select('table.review-ratings tr')})

        print(my_data)
        print("Table -->")
        print(my_data2)
       #. for td in table.children:
#       print(table)
         #   print(td[1])
        
       # e.td.text:len(e.select('.star.fill')) for e in soup.select('table.review-ratings tr')}

#    print(my_data)
#   for row in parsed_content.find_all("div", {"class": "review-stats"}):
##      table = row.find_all('table')[0]
 #      print(table)
        
#        review_details = pd.read_html(str(table))
#        print(review_details[0])
        
        #        header=row.find('td',class_='review-rating-header').text
#        value=row.find('td',class_='review-value')
#        if header=='Type Of Traveller':
#            print(header)
#            print(value.text)
            #Aircraft[0]=value.text
        
 

# div class review-ratings and then iterate through trs and tds... for a given rate... 


 #   for i, row in enumerate(parsed_content.find_all('tr')):
 #       if i == 0:
 #           header = [el.text.strip() for el in row.find_all('th')]
 #       else:
 #           rows.append([el.text.strip() for el in row.find_all('td')])
    
    #for para in parsed_content.find_all("div", {"class": "text_content"}):
#        reviews.append(para.get_text())

#rows = BeautifulSoup.find_all('tr')
#print(rows[:10])
    
#    for para2 in parsed_content.find_all("tr", {"class": "review-rating-header aircraft "}):
#           review_value.append(para2.get_text())
#           print(review_value)
    
#    print(f"   ---> {len(review_value)} review-rating-header aircraft ")
# Out:
# Scraping page 1
# {'Type Of Traveller': 'Solo Leisure'}
# {'Seat Type': 'Economy Class'}
# {'Route': 'London to Dallas'}
# {'Date Flown': 'April 2023'}
# {'Seat Comfort': 1}
# {'Cabin Staff Service': 1}
# {'Food & Beverages': 3}
# {'Inflight Entertainment': 3}
# {'Ground Service': 1}
# {'Wifi & Connectivity': 1}
# {'Value For Money': 1}
# {'Recommended': 'no'}
# {'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}
# Table -->
# [{'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}, {'Type Of Traveller': 'Solo Leisure'}, {'Seat Type': 'Economy Class'}, {'Route': 'London to Dallas'}, {'Date Flown': 'April 2023'}, {'Seat Comfort': 1}, {'Cabin Staff Service': 1}, {'Food & Beverages': 3}, {'Inflight Entertainment': 3}, {'Ground Service': 1}, {'Wifi & Connectivity': 1}, {'Value For Money': 1}, {'Recommended': 'no'}]
# {'Type Of Traveller': 'Business'}
# {'Seat Type': 'Economy Class'}
# {'Route': 'London to Madrid'}
# {'Date Flown': 'May 2023'}
# {'Seat Comfort': 4}
# {'Cabin Staff Service': 3}
# {'Food & Beverages': 1}
# {'Ground Service': 1}
# {'Value For Money': 1}
# {'Recommended': 'no'}
# {'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}
# Table -->
# [{'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}, {'Type Of Traveller': 'Business'}, {'Seat Type': 'Economy Class'}, {'Route': 'London to Madrid'}, {'Date Flown': 'May 2023'}, {'Seat Comfort': 4}, {'Cabin Staff Service': 3}, {'Food & Beverages': 1}, {'Ground Service': 1}, {'Value For Money': 1}, {'Recommended': 'no'}]
# {'Type Of Traveller': 'Solo Leisure'}
# {'Seat Type': 'Economy Class'}
# {'Route': 'London to Belfast'}
# {'Date Flown': 'May 2023'}
# {'Seat Comfort': 1}
# {'Cabin Staff Service': 3}
# {'Food & Beverages': 3}
# {'Inflight Entertainment': 1}
# {'Ground Service': 1}
# {'Wifi & Connectivity': 1}
# {'Value For Money': 1}
# {'Recommended': 'no'}
# {'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}
# Table -->
# [{'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}, {'Type Of Traveller': 'Solo Leisure'}, {'Seat Type': 'Economy Class'}, {'Route': 'London to Belfast'}, {'Date Flown': 'May 2023'}, {'Seat Comfort': 1}, {'Cabin Staff Service': 3}, {'Food & Beverages': 3}, {'Inflight Entertainment': 1}, {'Ground Service': 1}, {'Wifi & Connectivity': 1}, {'Value For Money': 1}, {'Recommended': 'no'}]
# {'Type Of Traveller': 'Couple Leisure'}
# {'Seat Type': 'Business Class'}
# {'Route': 'Los Angeles to London'}
# {'Date Flown': 'May 2023'}
# {'Seat Comfort': 5}
# {'Cabin Staff Service': 5}
# {'Food & Beverages': 4}
# {'Inflight Entertainment': 5}
# {'Ground Service': 1}
# {'Wifi & Connectivity': 2}
# {'Value For Money': 1}
# {'Recommended': 'no'}
# {'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}
# Table -->
# [{'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}, {'Type Of Traveller': 'Couple Leisure'}, {'Seat Type': 'Business Class'}, {'Route': 'Los Angeles to London'}, {'Date Flown': 'May 2023'}, {'Seat Comfort': 5}, {'Cabin Staff Service': 5}, {'Food & Beverages': 4}, {'Inflight Entertainment': 5}, {'Ground Service': 1}, {'Wifi & Connectivity': 2}, {'Value For Money': 1}, {'Recommended': 'no'}]
# {'Type Of Traveller': 'Couple Leisure'}
# {'Seat Type': 'Business Class'}
# {'Route': 'Atlanta to London'}
# {'Date Flown': 'April 2023'}
# {'Seat Comfort': 4}
# {'Cabin Staff Service': 3}
# {'Food & Beverages': 1}
# {'Inflight Entertainment': 2}
# {'Ground Service': 1}
# {'Wifi & Connectivity': 1}
# {'Value For Money': 1}
# {'Recommended': 'no'}
# {'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}
# Table -->
# [{'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}, {'Type Of Traveller': 'Couple Leisure'}, {'Seat Type': 'Business Class'}, {'Route': 'Atlanta to London'}, {'Date Flown': 'April 2023'}, {'Seat Comfort': 4}, {'Cabin Staff Service': 3}, {'Food & Beverages': 1}, {'Inflight Entertainment': 2}, {'Ground Service': 1}, {'Wifi & Connectivity': 1}, {'Value For Money': 1}, {'Recommended': 'no'}]
# {'Type Of Traveller': 'Couple Leisure'}
# {'Seat Type': 'Business Class'}
# {'Date Flown': 'May 2023'}
# {'Value For Money': 1}
# {'Recommended': 'no'}
# {'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}
# Table -->
# [{'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}, {'Type Of Traveller': 'Couple Leisure'}, {'Seat Type': 'Business Class'}, {'Date Flown': 'May 2023'}, {'Value For Money': 1}, {'Recommended': 'no'}]
# {'Aircraft': 'Boeing 787-9'}
# {'Type Of Traveller': 'Solo Leisure'}
# {'Seat Type': 'Business Class'}
# {'Route': 'Sydney to London via Singapore'}
# {'Date Flown': 'May 2023'}
# {'Seat Comfort': 1}
# {'Cabin Staff Service': 1}
# {'Food & Beverages': 1}
# {'Inflight Entertainment': 1}
# {'Ground Service': 1}
# {'Wifi & Connectivity': 1}
# {'Value For Money': 1}
# {'Recommended': 'no'}
# {'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}
# Table -->
# [{'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}, {'Aircraft': 'Boeing 787-9'}, {'Type Of Traveller': 'Solo Leisure'}, {'Seat Type': 'Business Class'}, {'Route': 'Sydney to London via Singapore'}, {'Date Flown': 'May 2023'}, {'Seat Comfort': 1}, {'Cabin Staff Service': 1}, {'Food & Beverages': 1}, {'Inflight Entertainment': 1}, {'Ground Service': 1}, {'Wifi & Connectivity': 1}, {'Value For Money': 1}, {'Recommended': 'no'}]
# {'Type Of Traveller': 'Solo Leisure'}
# {'Seat Type': 'Business Class'}
# {'Route': 'Heathrow to Faro'}
# {'Date Flown': 'May 2023'}
# {'Seat Comfort': 1}
# {'Cabin Staff Service': 1}
# {'Food & Beverages': 1}
# {'Inflight Entertainment': 1}
# {'Ground Service': 1}
# {'Wifi & Connectivity': 1}
# {'Value For Money': 1}
# {'Recommended': 'no'}
# {'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}
# Table -->
# [{'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}, {'Type Of Traveller': 'Solo Leisure'}, {'Seat Type': 'Business Class'}, {'Route': 'Heathrow to Faro'}, {'Date Flown': 'May 2023'}, {'Seat Comfort': 1}, {'Cabin Staff Service': 1}, {'Food & Beverages': 1}, {'Inflight Entertainment': 1}, {'Ground Service': 1}, {'Wifi & Connectivity': 1}, {'Value For Money': 1}, {'Recommended': 'no'}]
# {'Type Of Traveller': 'Business'}
# {'Seat Type': 'Economy Class'}
# {'Route': 'London to Barcelona'}
# {'Date Flown': 'May 2023'}
# {'Ground Service': 1}
# {'Value For Money': 1}
# {'Recommended': 'no'}
# {'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}
# Table -->
# [{'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}, {'Type Of Traveller': 'Business'}, {'Seat Type': 'Economy Class'}, {'Route': 'London to Barcelona'}, {'Date Flown': 'May 2023'}, {'Ground Service': 1}, {'Value For Money': 1}, {'Recommended': 'no'}]
# {'Type Of Traveller': 'Business'}
# {'Seat Type': 'Economy Class'}
# {'Route': 'New York to London'}
# {'Date Flown': 'April 2023'}
# {'Seat Comfort': 4}
# {'Cabin Staff Service': 3}
# {'Food & Beverages': 3}
# {'Inflight Entertainment': 3}
# {'Ground Service': 1}
# {'Wifi & Connectivity': 4}
# {'Value For Money': 1}
# {'Recommended': 'no'}
# {'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}
# Table -->
# [{'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}, {'Type Of Traveller': 'Business'}, {'Seat Type': 'Economy Class'}, {'Route': 'New York to London'}, {'Date Flown': 'April 2023'}, {'Seat Comfort': 4}, {'Cabin Staff Service': 3}, {'Food & Beverages': 3}, {'Inflight Entertainment': 3}, {'Ground Service': 1}, {'Wifi & Connectivity': 4}, {'Value For Money': 1}, {'Recommended': 'no'}]
# {'Aircraft': 'Boeing 787'}
# {'Type Of Traveller': 'Couple Leisure'}
# {'Seat Type': 'Business Class'}
# {'Route': 'Singapore to London'}
# {'Date Flown': 'April 2023'}
# {'Seat Comfort': 4}
# {'Cabin Staff Service': 2}
# {'Food & Beverages': 1}
# {'Inflight Entertainment': 5}
# {'Ground Service': 3}
# {'Wifi & Connectivity': 1}
# {'Value For Money': 1}
# {'Recommended': 'no'}
# {'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}
# Table -->
# [{'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}, {'Aircraft': 'Boeing 787'}, {'Type Of Traveller': 'Couple Leisure'}, {'Seat Type': 'Business Class'}, {'Route': 'Singapore to London'}, {'Date Flown': 'April 2023'}, {'Seat Comfort': 4}, {'Cabin Staff Service': 2}, {'Food & Beverages': 1}, {'Inflight Entertainment': 5}, {'Ground Service': 3}, {'Wifi & Connectivity': 1}, {'Value For Money': 1}, {'Recommended': 'no'}]
# {'Type Of Traveller': 'Couple Leisure'}
# {'Seat Type': 'Economy Class'}
# {'Route': 'Sweden to Los Angeles via London'}
# {'Date Flown': 'January 2023'}
# {'Seat Comfort': 3}
# {'Cabin Staff Service': 3}
# {'Food & Beverages': 3}
# {'Inflight Entertainment': 2}
# {'Ground Service': 3}
# {'Value For Money': 1}
# {'Recommended': 'no'}
# {'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}
# Table -->
# [{'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}, {'Type Of Traveller': 'Couple Leisure'}, {'Seat Type': 'Economy Class'}, {'Route': 'Sweden to Los Angeles via London'}, {'Date Flown': 'January 2023'}, {'Seat Comfort': 3}, {'Cabin Staff Service': 3}, {'Food & Beverages': 3}, {'Inflight Entertainment': 2}, {'Ground Service': 3}, {'Value For Money': 1}, {'Recommended': 'no'}]
# {'Aircraft': 'Boeing 777'}
# {'Type Of Traveller': 'Couple Leisure'}
# {'Seat Type': 'Premium Economy'}
# {'Route': 'Seattle to Zagreb via London'}
# {'Date Flown': 'April 2023'}
# {'Seat Comfort': 3}
# {'Cabin Staff Service': 2}
# {'Food & Beverages': 1}
# {'Inflight Entertainment': 1}
# {'Ground Service': 3}
# {'Wifi & Connectivity': 1}
# {'Value For Money': 2}
# {'Recommended': 'no'}
# {'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}
# Table -->
# [{'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}, {'Aircraft': 'Boeing 777'}, {'Type Of Traveller': 'Couple Leisure'}, {'Seat Type': 'Premium Economy'}, {'Route': 'Seattle to Zagreb via London'}, {'Date Flown': 'April 2023'}, {'Seat Comfort': 3}, {'Cabin Staff Service': 2}, {'Food & Beverages': 1}, {'Inflight Entertainment': 1}, {'Ground Service': 3}, {'Wifi & Connectivity': 1}, {'Value For Money': 2}, {'Recommended': 'no'}]
# {'Aircraft': 'Boeing 777'}
# {'Type Of Traveller': 'Family Leisure'}
# {'Seat Type': 'Premium Economy'}
# {'Route': 'Bangalore to Toronto via London, '}
# {'Date Flown': 'April 2023'}
# {'Seat Comfort': 2}
# {'Cabin Staff Service': 1}
# {'Food & Beverages': 2}
# {'Inflight Entertainment': 3}
# {'Ground Service': 1}
# {'Value For Money': 1}
# {'Recommended': 'no'}
# {'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}
# Table -->
# [{'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}, {'Aircraft': 'Boeing 777'}, {'Type Of Traveller': 'Family Leisure'}, {'Seat Type': 'Premium Economy'}, {'Route': 'Bangalore to Toronto via London, '}, {'Date Flown': 'April 2023'}, {'Seat Comfort': 2}, {'Cabin Staff Service': 1}, {'Food & Beverages': 2}, {'Inflight Entertainment': 3}, {'Ground Service': 1}, {'Value For Money': 1}, {'Recommended': 'no'}]
# {'Aircraft': 'Dreamliner'}
# {'Type Of Traveller': 'Family Leisure'}
# {'Seat Type': 'Economy Class'}
# {'Route': 'London to Denver'}
# {'Date Flown': 'February 2023'}
# {'Seat Comfort': 2}
# {'Cabin Staff Service': 1}
# {'Food & Beverages': 1}
# {'Inflight Entertainment': 3}
# {'Ground Service': 1}
# {'Wifi & Connectivity': 1}
# {'Value For Money': 2}
# {'Recommended': 'no'}
# {'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}
# Table -->
# [{'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}, {'Aircraft': 'Dreamliner'}, {'Type Of Traveller': 'Family Leisure'}, {'Seat Type': 'Economy Class'}, {'Route': 'London to Denver'}, {'Date Flown': 'February 2023'}, {'Seat Comfort': 2}, {'Cabin Staff Service': 1}, {'Food & Beverages': 1}, {'Inflight Entertainment': 3}, {'Ground Service': 1}, {'Wifi & Connectivity': 1}, {'Value For Money': 2}, {'Recommended': 'no'}]
# {'Aircraft': 'A350'}
# {'Type Of Traveller': 'Solo Leisure'}
# {'Seat Type': 'Premium Economy'}
# {'Route': 'London to Hong Kong'}
# {'Date Flown': 'April 2023'}
# {'Seat Comfort': 4}
# {'Cabin Staff Service': 5}
# {'Food & Beverages': 4}
# {'Inflight Entertainment': 3}
# {'Ground Service': 4}
# {'Value For Money': 4}
# {'Recommended': 'yes'}
# {'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}
# Table -->
# [{'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}, {'Aircraft': 'A350'}, {'Type Of Traveller': 'Solo Leisure'}, {'Seat Type': 'Premium Economy'}, {'Route': 'London to Hong Kong'}, {'Date Flown': 'April 2023'}, {'Seat Comfort': 4}, {'Cabin Staff Service': 5}, {'Food & Beverages': 4}, {'Inflight Entertainment': 3}, {'Ground Service': 4}, {'Value For Money': 4}, {'Recommended': 'yes'}]
# {'Type Of Traveller': 'Couple Leisure'}
# {'Seat Type': 'Economy Class'}
# {'Route': 'Brussels to Los Angeles via London Heathrow'}
# {'Date Flown': 'April 2023'}
# {'Seat Comfort': 1}
# {'Cabin Staff Service': 4}
# {'Food & Beverages': 1}
# {'Inflight Entertainment': 3}
# {'Ground Service': 1}
# {'Wifi & Connectivity': 1}
# {'Value For Money': 1}
# {'Recommended': 'no'}
# {'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}
# Table -->
# [{'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}, {'Type Of Traveller': 'Couple Leisure'}, {'Seat Type': 'Economy Class'}, {'Route': 'Brussels to Los Angeles via London Heathrow'}, {'Date Flown': 'April 2023'}, {'Seat Comfort': 1}, {'Cabin Staff Service': 4}, {'Food & Beverages': 1}, {'Inflight Entertainment': 3}, {'Ground Service': 1}, {'Wifi & Connectivity': 1}, {'Value For Money': 1}, {'Recommended': 'no'}]
# {'Type Of Traveller': 'Couple Leisure'}
# {'Seat Type': 'Economy Class'}
# {'Route': 'Copenhagen to London'}
# {'Date Flown': 'April 2023'}
# {'Seat Comfort': 1}
# {'Cabin Staff Service': 4}
# {'Food & Beverages': 2}
# {'Ground Service': 2}
# {'Value For Money': 2}
# {'Recommended': 'no'}
# {'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}
# Table -->
# [{'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}, {'Type Of Traveller': 'Couple Leisure'}, {'Seat Type': 'Economy Class'}, {'Route': 'Copenhagen to London'}, {'Date Flown': 'April 2023'}, {'Seat Comfort': 1}, {'Cabin Staff Service': 4}, {'Food & Beverages': 2}, {'Ground Service': 2}, {'Value For Money': 2}, {'Recommended': 'no'}]
# {'Type Of Traveller': 'Family Leisure'}
# {'Seat Type': 'Economy Class'}
# {'Route': 'London to Denver'}
# {'Date Flown': 'March 2023'}
# {'Seat Comfort': 2}
# {'Cabin Staff Service': 5}
# {'Food & Beverages': 2}
# {'Inflight Entertainment': 3}
# {'Ground Service': 4}
# {'Wifi & Connectivity': 1}
# {'Value For Money': 1}
# {'Recommended': 'no'}
# {'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}
# Table -->
# [{'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}, {'Type Of Traveller': 'Family Leisure'}, {'Seat Type': 'Economy Class'}, {'Route': 'London to Denver'}, {'Date Flown': 'March 2023'}, {'Seat Comfort': 2}, {'Cabin Staff Service': 5}, {'Food & Beverages': 2}, {'Inflight Entertainment': 3}, {'Ground Service': 4}, {'Wifi & Connectivity': 1}, {'Value For Money': 1}, {'Recommended': 'no'}]
# {'Type Of Traveller': 'Solo Leisure'}
# {'Seat Type': 'Economy Class'}
# {'Route': 'Hong Kong to London'}
# {'Date Flown': 'April 2023'}
# {'Seat Comfort': 2}
# {'Cabin Staff Service': 1}
# {'Food & Beverages': 1}
# {'Inflight Entertainment': 1}
# {'Ground Service': 2}
# {'Wifi & Connectivity': 1}
# {'Value For Money': 2}
# {'Recommended': 'no'}
# {'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}
# Table -->
# [{'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}, {'Type Of Traveller': 'Solo Leisure'}, {'Seat Type': 'Economy Class'}, {'Route': 'Hong Kong to London'}, {'Date Flown': 'April 2023'}, {'Seat Comfort': 2}, {'Cabin Staff Service': 1}, {'Food & Beverages': 1}, {'Inflight Entertainment': 1}, {'Ground Service': 2}, {'Wifi & Connectivity': 1}, {'Value For Money': 2}, {'Recommended': 'no'}]
# {'Aircraft': 'A320'}
# {'Type Of Traveller': 'Business'}
# {'Seat Type': 'Business Class'}
# {'Route': 'Heathrow to Malaga'}
# {'Date Flown': 'April 2023'}
# {'Seat Comfort': 3}
# {'Cabin Staff Service': 3}
# {'Food & Beverages': 4}
# {'Ground Service': 3}
# {'Wifi & Connectivity': 1}
# {'Value For Money': 2}
# {'Recommended': 'no'}
# {'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}
# Table -->
# [{'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}, {'Aircraft': 'A320'}, {'Type Of Traveller': 'Business'}, {'Seat Type': 'Business Class'}, {'Route': 'Heathrow to Malaga'}, {'Date Flown': 'April 2023'}, {'Seat Comfort': 3}, {'Cabin Staff Service': 3}, {'Food & Beverages': 4}, {'Ground Service': 3}, {'Wifi & Connectivity': 1}, {'Value For Money': 2}, {'Recommended': 'no'}]
# {'Type Of Traveller': 'Family Leisure'}
# {'Seat Type': 'Economy Class'}
# {'Route': 'Santorini to Gatwick'}
# {'Date Flown': 'March 2023'}
# {'Seat Comfort': 4}
# {'Cabin Staff Service': 4}
# {'Inflight Entertainment': 1}
# {'Ground Service': 3}
# {'Wifi & Connectivity': 3}
# {'Value For Money': 1}
# {'Recommended': 'no'}
# {'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}
# Table -->
# [{'Comment': '✅ Trip Verified |  Absolutely terrible experience. The app would not let me check in online and repeatedly asked for COVID documents, but then did not accept them even when provided. I was trying to fly back to the USA, where I am a citizen and the app caused repeated errors. I went to British Airways Customer Service to check in and was told that my seat was already given away to another passenger, even though I was there in plenty of time. This was also during an industrial action at Heathrow, meaning the number of flights were limited. I was delayed over 24 hours in returning to the USA, all because of their terrible app and then bad customer service that gives away seats even when the paid passenger is already there at the airport.'}, {'Type Of Traveller': 'Family Leisure'}, {'Seat Type': 'Economy Class'}, {'Route': 'Santorini to Gatwick'}, {'Date Flown': 'March 2023'}, {'Seat Comfort': 4}, {'Cabin Staff Service': 4}, {'Inflight Entertainment': 1}, {'Ground Service': 3}, {'Wifi & Connectivity': 3}, {'Value For Money': 1}, {'Recommended': 'no'}]
# {'Type Of Traveller': 'Solo Leisure'}
# {'Seat Type': 'Economy Class'}
# {'Route': 'Madrid to Belfast via London'}
# {'Date Flown': 'January 2023'}
# {'Seat Comfort': 3}
# {'Cabin Staff Service': 3}
# {'Food & Beverages': 2}
# {'Ground Service': 1}
# {'Value For Money': 1}
# ...
# {'Aircraft': 'Boeing 777-200'}
# {'Type Of Traveller': 'Couple Leisure'}
# {'Seat Type': 'Business Class'}
# {'Route': 'London to Cape Town'}
# {'Date Flown': 'March 2022'}
# {'Seat Comfort': 3}
# {'Cabin Staff Service': 3}
# {'Food & Beverages': 2}
# {'Inflight Entertainment': 1}
# {'Ground Service': 3}
# {'Value For Money': 3}
# {'Recommended': 'no'}
# {'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}
# Table -->
# [{'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}, {'Aircraft': 'Boeing 777-200'}, {'Type Of Traveller': 'Couple Leisure'}, {'Seat Type': 'Business Class'}, {'Route': 'London to Cape Town'}, {'Date Flown': 'March 2022'}, {'Seat Comfort': 3}, {'Cabin Staff Service': 3}, {'Food & Beverages': 2}, {'Inflight Entertainment': 1}, {'Ground Service': 3}, {'Value For Money': 3}, {'Recommended': 'no'}]
# {'Aircraft': 'A320'}
# {'Type Of Traveller': 'Couple Leisure'}
# {'Seat Type': 'Business Class'}
# {'Route': 'Lisbon to London'}
# {'Date Flown': 'February 2022'}
# {'Seat Comfort': 1}
# {'Cabin Staff Service': 3}
# {'Food & Beverages': 1}
# {'Ground Service': 3}
# {'Value For Money': 1}
# {'Recommended': 'no'}
# {'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}
# Table -->
# [{'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}, {'Aircraft': 'A320'}, {'Type Of Traveller': 'Couple Leisure'}, {'Seat Type': 'Business Class'}, {'Route': 'Lisbon to London'}, {'Date Flown': 'February 2022'}, {'Seat Comfort': 1}, {'Cabin Staff Service': 3}, {'Food & Beverages': 1}, {'Ground Service': 3}, {'Value For Money': 1}, {'Recommended': 'no'}]
# {'Aircraft': 'A350'}
# {'Type Of Traveller': 'Solo Leisure'}
# {'Seat Type': 'Premium Economy'}
# {'Route': 'Vancouver to London'}
# {'Date Flown': 'February 2022'}
# {'Seat Comfort': 4}
# {'Cabin Staff Service': 5}
# {'Food & Beverages': 5}
# {'Inflight Entertainment': 5}
# {'Ground Service': 4}
# {'Wifi & Connectivity': 4}
# {'Value For Money': 5}
# {'Recommended': 'yes'}
# {'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}
# Table -->
# [{'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}, {'Aircraft': 'A350'}, {'Type Of Traveller': 'Solo Leisure'}, {'Seat Type': 'Premium Economy'}, {'Route': 'Vancouver to London'}, {'Date Flown': 'February 2022'}, {'Seat Comfort': 4}, {'Cabin Staff Service': 5}, {'Food & Beverages': 5}, {'Inflight Entertainment': 5}, {'Ground Service': 4}, {'Wifi & Connectivity': 4}, {'Value For Money': 5}, {'Recommended': 'yes'}]
# {'Aircraft': 'A320'}
# {'Type Of Traveller': 'Business'}
# {'Seat Type': 'Business Class'}
# {'Route': 'London to Malaga'}
# {'Date Flown': 'February 2022'}
# {'Seat Comfort': 3}
# {'Cabin Staff Service': 3}
# {'Food & Beverages': 2}
# {'Ground Service': 3}
# {'Wifi & Connectivity': 3}
# {'Value For Money': 2}
# {'Recommended': 'no'}
# {'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}
# Table -->
# [{'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}, {'Aircraft': 'A320'}, {'Type Of Traveller': 'Business'}, {'Seat Type': 'Business Class'}, {'Route': 'London to Malaga'}, {'Date Flown': 'February 2022'}, {'Seat Comfort': 3}, {'Cabin Staff Service': 3}, {'Food & Beverages': 2}, {'Ground Service': 3}, {'Wifi & Connectivity': 3}, {'Value For Money': 2}, {'Recommended': 'no'}]
# {'Aircraft': 'A322'}
# {'Type Of Traveller': 'Business'}
# {'Seat Type': 'Economy Class'}
# {'Route': 'London to Athens'}
# {'Date Flown': 'February 2022'}
# {'Seat Comfort': 2}
# {'Cabin Staff Service': 3}
# {'Food & Beverages': 1}
# {'Ground Service': 1}
# {'Value For Money': 1}
# {'Recommended': 'no'}
# {'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}
# Table -->
# [{'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}, {'Aircraft': 'A322'}, {'Type Of Traveller': 'Business'}, {'Seat Type': 'Economy Class'}, {'Route': 'London to Athens'}, {'Date Flown': 'February 2022'}, {'Seat Comfort': 2}, {'Cabin Staff Service': 3}, {'Food & Beverages': 1}, {'Ground Service': 1}, {'Value For Money': 1}, {'Recommended': 'no'}]
# {'Type Of Traveller': 'Solo Leisure'}
# {'Seat Type': 'Economy Class'}
# {'Route': 'London to Edinburgh'}
# {'Date Flown': 'February 2022'}
# {'Ground Service': 1}
# {'Value For Money': 1}
# {'Recommended': 'no'}
# {'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}
# Table -->
# [{'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}, {'Type Of Traveller': 'Solo Leisure'}, {'Seat Type': 'Economy Class'}, {'Route': 'London to Edinburgh'}, {'Date Flown': 'February 2022'}, {'Ground Service': 1}, {'Value For Money': 1}, {'Recommended': 'no'}]
# {'Aircraft': 'Boeing 787-9'}
# {'Type Of Traveller': 'Family Leisure'}
# {'Seat Type': 'Business Class'}
# {'Route': 'Washington to London'}
# {'Date Flown': 'February 2022'}
# {'Seat Comfort': 4}
# {'Cabin Staff Service': 5}
# {'Food & Beverages': 4}
# {'Inflight Entertainment': 4}
# {'Ground Service': 5}
# {'Wifi & Connectivity': 4}
# {'Value For Money': 4}
# {'Recommended': 'yes'}
# {'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}
# Table -->
# [{'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}, {'Aircraft': 'Boeing 787-9'}, {'Type Of Traveller': 'Family Leisure'}, {'Seat Type': 'Business Class'}, {'Route': 'Washington to London'}, {'Date Flown': 'February 2022'}, {'Seat Comfort': 4}, {'Cabin Staff Service': 5}, {'Food & Beverages': 4}, {'Inflight Entertainment': 4}, {'Ground Service': 5}, {'Wifi & Connectivity': 4}, {'Value For Money': 4}, {'Recommended': 'yes'}]
# {'Type Of Traveller': 'Couple Leisure'}
# {'Seat Type': 'Economy Class'}
# {'Route': 'Accra to London '}
# {'Date Flown': 'January 2022'}
# {'Seat Comfort': 1}
# {'Cabin Staff Service': 2}
# {'Food & Beverages': 1}
# {'Inflight Entertainment': 1}
# {'Ground Service': 1}
# {'Wifi & Connectivity': 1}
# {'Value For Money': 1}
# {'Recommended': 'no'}
# {'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}
# Table -->
# [{'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}, {'Type Of Traveller': 'Couple Leisure'}, {'Seat Type': 'Economy Class'}, {'Route': 'Accra to London '}, {'Date Flown': 'January 2022'}, {'Seat Comfort': 1}, {'Cabin Staff Service': 2}, {'Food & Beverages': 1}, {'Inflight Entertainment': 1}, {'Ground Service': 1}, {'Wifi & Connectivity': 1}, {'Value For Money': 1}, {'Recommended': 'no'}]
# {'Aircraft': 'A320'}
# {'Type Of Traveller': 'Business'}
# {'Seat Type': 'Business Class'}
# {'Route': 'Dublin to London'}
# {'Date Flown': 'February 2022'}
# {'Value For Money': 1}
# {'Recommended': 'no'}
# {'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}
# Table -->
# [{'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}, {'Aircraft': 'A320'}, {'Type Of Traveller': 'Business'}, {'Seat Type': 'Business Class'}, {'Route': 'Dublin to London'}, {'Date Flown': 'February 2022'}, {'Value For Money': 1}, {'Recommended': 'no'}]
# {'Aircraft': 'Boeing 787-9'}
# {'Type Of Traveller': 'Family Leisure'}
# {'Seat Type': 'Business Class'}
# {'Route': 'London to Washington'}
# {'Date Flown': 'February 2022'}
# {'Seat Comfort': 4}
# {'Cabin Staff Service': 5}
# {'Food & Beverages': 5}
# {'Inflight Entertainment': 4}
# {'Ground Service': 5}
# {'Wifi & Connectivity': 5}
# {'Value For Money': 4}
# {'Recommended': 'yes'}
# {'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}
# Table -->
# [{'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}, {'Aircraft': 'Boeing 787-9'}, {'Type Of Traveller': 'Family Leisure'}, {'Seat Type': 'Business Class'}, {'Route': 'London to Washington'}, {'Date Flown': 'February 2022'}, {'Seat Comfort': 4}, {'Cabin Staff Service': 5}, {'Food & Beverages': 5}, {'Inflight Entertainment': 4}, {'Ground Service': 5}, {'Wifi & Connectivity': 5}, {'Value For Money': 4}, {'Recommended': 'yes'}]
# {'Type Of Traveller': 'Family Leisure'}
# {'Seat Type': 'Business Class'}
# {'Route': 'London to Porto'}
# {'Date Flown': 'February 2022'}
# {'Value For Money': 1}
# {'Recommended': 'no'}
# {'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}
# Table -->
# [{'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}, {'Type Of Traveller': 'Family Leisure'}, {'Seat Type': 'Business Class'}, {'Route': 'London to Porto'}, {'Date Flown': 'February 2022'}, {'Value For Money': 1}, {'Recommended': 'no'}]
# {'Type Of Traveller': 'Solo Leisure'}
# {'Seat Type': 'Business Class'}
# {'Route': 'Washington to London'}
# {'Date Flown': 'December 2021'}
# {'Seat Comfort': 5}
# {'Cabin Staff Service': 5}
# {'Food & Beverages': 5}
# {'Ground Service': 4}
# {'Value For Money': 5}
# {'Recommended': 'yes'}
# {'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}
# Table -->
# [{'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}, {'Type Of Traveller': 'Solo Leisure'}, {'Seat Type': 'Business Class'}, {'Route': 'Washington to London'}, {'Date Flown': 'December 2021'}, {'Seat Comfort': 5}, {'Cabin Staff Service': 5}, {'Food & Beverages': 5}, {'Ground Service': 4}, {'Value For Money': 5}, {'Recommended': 'yes'}]
# {'Type Of Traveller': 'Couple Leisure'}
# {'Seat Type': 'Economy Class'}
# {'Route': 'Montréal to Dubai via London'}
# {'Date Flown': 'February 2022'}
# {'Value For Money': 4}
# {'Recommended': 'yes'}
# {'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}
# Table -->
# [{'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}, {'Type Of Traveller': 'Couple Leisure'}, {'Seat Type': 'Economy Class'}, {'Route': 'Montréal to Dubai via London'}, {'Date Flown': 'February 2022'}, {'Value For Money': 4}, {'Recommended': 'yes'}]
# {'Aircraft': 'Boeing 787-9'}
# {'Type Of Traveller': 'Couple Leisure'}
# {'Seat Type': 'Business Class'}
# {'Route': 'Atlanta to Belfast via Heathrow'}
# {'Date Flown': 'January 2022'}
# {'Seat Comfort': 4}
# {'Cabin Staff Service': 5}
# {'Food & Beverages': 4}
# {'Inflight Entertainment': 4}
# {'Ground Service': 5}
# {'Value For Money': 5}
# {'Recommended': 'yes'}
# {'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}
# Table -->
# [{'Comment': 'Not Verified |  The flight was delayed over 6 hours and this of course caused us to missed our connection flight and change to a different route, finally I lost my luggage and no one has any information. I will never again travel with British Airways.'}, {'Aircraft': 'Boeing 787-9'}, {'Type Of Traveller': 'Couple Leisure'}, {'Seat Type': 'Business Class'}, {'Route': 'Atlanta to Belfast via Heathrow'}, {'Date Flown': 'January 2022'}, {'Seat Comfort': 4}, {'Cabin Staff Service': 5}, {'Food & Beverages': 4}, {'Inflight Entertainment': 4}, {'Ground Service': 5}, {'Value For Money': 5}, {'Recommended': 'yes'}]

# %%
#df = pd.DataFrame()
#df["reviews"] = reviews
#df
df2 = pd.DataFrame()
df2["rows"] = rows
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7e9b1e2fc93d> in <module>
#       3 #df
#       4 df2 = pd.DataFrame()
# ----> 5 df2["rows"] = rows
#       6 df2
#
# NameError: name 'rows' is not defined

# %%
df.to_csv("data/BA_reviews.csv")

# %% [markdown]
# Congratulations! Now you have your dataset for this task! The loops above collected 1000 reviews by iterating through the paginated pages on the website. However, if you want to collect more data, try increasing the number of pages!
#
#  The next thing that you should do is clean this data to remove any unnecessary text from each of the rows. For example, "✅ Trip Verified" can be removed from each row if it exists, as it's not relevant to what we want to investigate.

# %%
df
# Out:
#                                                reviews
# 0    ✅ Trip Verified |  I will never travel with Br...
# 1    ✅ Trip Verified |  I am already in Portugal so...
# 2    ✅ Trip Verified |  Terrible. Avoid this airlin...
# 3    ✅ Trip Verified |  Despite being a gold member...
# 4    Not Verified | Regarding the aircraft and seat...
# ..                                                 ...
# 995  ✅ Trip Verified |  Had four flights in total w...
# 996  ✅ Trip Verified |  Johannesburg to Heathrow. B...
# 997  ✅ Trip Verified |  The queue for bag drop was ...
# 998  ✅ Trip Verified |  British Airways changed pla...
# 999  ✅ Trip Verified |  Mumbai to Edinburgh via Lon...
#
# [1000 rows x 1 columns]
